# %% [markdown]
# # 1-Preprocessing part

# %%
#Importing the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
A=pd.read_csv(r"C:\\Users\LENOVO\Downloads\titanic.csv")
A
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#showing the head of the dataset
A.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#showing some general information
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
A.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#finding missing value
A.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#replacing missing value
A['Age'].fillna(A['Age'].mean(),inplace=True)
A
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
A['Age'].value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 55.500000      1
# 53.000000      1
# 20.500000      1
# 23.500000      1
# 0.420000       1
# Name: Age, Length: 89, dtype: int64

# %%
#label enconding for 'Sex' feature
S=A['Sex']
s={'Sex':{'male':1,'female':0}}
A.replace(s,inplace=True)
A
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
#one hot encoding for 'Embarked feature'
Z=pd.get_dummies(A['Embarked'])
A=A.drop('Embarked',axis=1)
A=A.join(Z)
A
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
#filtering columns
A1=A.filter(['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S'])
A1
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  C  Q  S
# 0           0       3    1  22.000000      1      0   7.2500  0  0  1
# 1           1       1    0  38.000000      1      0  71.2833  1  0  0
# 2           1       3    0  26.000000      0      0   7.9250  0  0  1
# 3           1       1    0  35.000000      1      0  53.1000  0  0  1
# 4           0       3    1  35.000000      0      0   8.0500  0  0  1
# ..        ...     ...  ...        ...    ...    ...      ... .. .. ..
# 886         0       2    1  27.000000      0      0  13.0000  0  0  1
# 887         1       1    0  19.000000      0      0  30.0000  0  0  1
# 888         0       3    0  29.699118      1      2  23.4500  0  0  1
# 889         1       1    1  26.000000      0      0  30.0000  1  0  0
# 890         0       3    1  32.000000      0      0   7.7500  0  1  0
#
# [891 rows x 10 columns]

# %% [markdown]
# # 2- visualization part

# %%
#analysing variables distribution
A1.hist(figsize = [15,15])
plt.show()

# %%
#correlation between Age, Sex ,Survived 
AS=A1.filter(['Age','Sex'])
f=sns.FacetGrid(AS,col='Sex')
f.map(plt.hist,'Age',bins=10)

# %%
grid = sns.FacetGrid(A1, row="Survived", col="Survived", size=2.2, aspect=2)
grid.map(sns.barplot, "Pclass", 'SibSp', alpha=.6, ci=None)
grid.add_legend()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#the relation between Pclass ans Survived
A1[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
#the relation between Pclass ans Survived
A1[['SibSp','Survived']].groupby(['SibSp'],as_index=True).mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
# the correlation map
def plot_correlation_map( A1 ):
    corr = A1.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(corr, cmap = cmap,square=True, cbar_kws={ 'shrink' : .9 },ax=ax,annot = True, annot_kws = { 'fontsize' : 12 })
plot_correlation_map(A1)

# %% [raw]
#     After running the function plot_correlation_map we obtain a map or a matrix.
#     The map shows  the relationship between variables that compose the dataset and how they are dependent upon each other .this dependancy is represented by the correlation coefficient wich have a range between -1 and 1 for instance the Fare variable (ticket price) is positively correlated with sibsp (Number of Siblings/Spouses Aboard) and Parch variable(number of parents) it means that if the passenger is with his spouse or children  abroad he wil pay more money for the ticket .Inversly the Fare variable is negatively correlated with Pclass(Passenger Class)variable that s mean higher is the number of class that the passenger choose lesser he wil pay.
#     The matrix is a great tools that shows how inputs(features) are related to eachothers and also to the output(the target)

# %%
A3=A.filter(['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S'])
A3
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  C  Q  S
# 0           0       3    1  22.000000      1      0   7.2500  0  0  1
# 1           1       1    0  38.000000      1      0  71.2833  1  0  0
# 2           1       3    0  26.000000      0      0   7.9250  0  0  1
# 3           1       1    0  35.000000      1      0  53.1000  0  0  1
# 4           0       3    1  35.000000      0      0   8.0500  0  0  1
# ..        ...     ...  ...        ...    ...    ...      ... .. .. ..
# 886         0       2    1  27.000000      0      0  13.0000  0  0  1
# 887         1       1    0  19.000000      0      0  30.0000  0  0  1
# 888         0       3    0  29.699118      1      2  23.4500  0  0  1
# 889         1       1    1  26.000000      0      0  30.0000  1  0  0
# 890         0       3    1  32.000000      0      0   7.7500  0  1  0
#
# [891 rows x 10 columns]

# %%
import re
A4=A.filter(['Name','Survived','Pclass','Sex','Age','SibSp','Parch','Fare','C','Q','S'])
Title=[]
for i in A['Name']:
    x = re.split("\s",str(i))
    Title.append(x[1])
A4['Title']=Title
A4
# Out:
#                                                   Name  Survived  Pclass  Sex  \
# 0                              Braund, Mr. Owen Harris         0       3    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1    0
# 2                               Heikkinen, Miss. Laina         1       3    0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1    0
# 4                             Allen, Mr. William Henry         0       3    1
# ..                                                 ...       ...     ...  ...
# 886                              Montvila, Rev. Juozas         0       2    1
# 887                       Graham, Miss. Margaret Edith         1       1    0
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3    0
# 889                              Behr, Mr. Karl Howell         1       1    1
# 890                                Dooley, Mr. Patrick         0       3    1
#
# ...

# %%
A4['Title'].value_counts()
# Out:
# Mr.             502
# Miss.           179
# Mrs.            121
# Master.          40
# Dr.               7
# Rev.              6
# y                 4
# Impe,             3
# Planke,           3
# Gordon,           2
# Mlle.             2
# Major.            2
# Col.              2
# Carlo,            1
# the               1
# Cruyssen,         1
# der               1
# Don.              1
# Ms.               1
# Messemaeker,      1
# Jonkheer.         1
# Velde,            1
# Walle,            1
# Capt.             1
# Melkebeke,        1
# Mulder,           1
# Billiard,         1
# Steen,            1
# Mme.              1
# Pelsmaeker,       1
# Shawah,           1
# Name: Title, dtype: int64

# %%
#Label encoder for Title using sKlearn 
from sklearn.preprocessing import LabelEncoder 
A5=A4.filter(['Survived','Sex','Fare','Age','Title'])
encoder=LabelEncoder()
A5['Title']=encoder.fit_transform(A5['Title'])
A5
#correlation between Title and other features
plot_correlation_map(A5)

# %%
T=A4['Title']
t={'Title':{'Capt.':'Officer','Col.':'Officer','Major.':'Officer','Dr.':'Officer','Rev.':'Officer'}}
A4 . replace(t,inplace=True)
t1={'Title':{'Don.':'Royalty','Jonkheer.':'Royalty','Sir.':'Royalty','Lady.':'Royalty','the_Countess.':'Royalty','Dona.':'Royalty'}}
A4 . replace(t1,inplace=True)
t2={'Title':{'Mme.':'Miss','Mlle.':'Miss','Miss.':'Miss'}}
A4 . replace(t2,inplace=True)
t3={'Title':{"Master.":'Master'}}
A4 . replace(t3,inplace=True)
t4={'Title':{'Mr.':'Mrs','Ms.':'Mrs','Mrs.':'Mrs'}}
A4 . replace(t4,inplace=True)
A4
# Out:
#                                                   Name  Survived  Pclass  Sex  \
# 0                              Braund, Mr. Owen Harris         0       3    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1    0
# 2                               Heikkinen, Miss. Laina         1       3    0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1    0
# 4                             Allen, Mr. William Henry         0       3    1
# ..                                                 ...       ...     ...  ...
# 886                              Montvila, Rev. Juozas         0       2    1
# 887                       Graham, Miss. Margaret Edith         1       1    0
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3    0
# 889                              Behr, Mr. Karl Howell         1       1    1
# 890                                Dooley, Mr. Patrick         0       3    1
#
# ...

# %%
A4['Title'].value_counts()
# Out:
# Mrs             624
# Miss            182
# Master           40
# Officer          18
# y                 4
# Impe,             3
# Planke,           3
# Royalty           2
# Gordon,           2
# the               1
# Walle,            1
# der               1
# Messemaeker,      1
# Pelsmaeker,       1
# Mulder,           1
# Carlo,            1
# Steen,            1
# Cruyssen,         1
# Velde,            1
# Billiard,         1
# Melkebeke,        1
# Shawah,           1
# Name: Title, dtype: int64

# %%
A5=A4.filter(['Survived','Sex','Fare','Age','Title'])
encoder=LabelEncoder()
A5['Title']=encoder.fit_transform(A5['Title'])

plot_correlation_map(A5)

# %%
A4[['Title','Survived','Age','Fare','Sex']].groupby(['Title'],as_index=True).mean()
# Out:
#               Survived        Age       Fare       Sex
# Title
# Billiard,     0.000000  40.500000  14.500000  1.000000
# Carlo,        0.000000  29.000000  27.720800  1.000000
# Cruyssen,     0.000000  47.000000   9.000000  1.000000
# Gordon,       1.000000  48.500000  48.264600  0.500000
# Impe,         0.000000  25.333333  24.150000  0.333333
# Master        0.575000   7.086662  34.703125  1.000000
# Melkebeke,    0.000000  29.699118   9.500000  1.000000
# Messemaeker,  1.000000  36.000000  17.400000  0.000000
# Miss          0.708791  23.434990  44.523674  0.000000
# Mrs           0.283654  32.436990  28.540530  0.804487
# Mulder,       1.000000  30.000000   9.500000  1.000000
# Officer       0.277778  45.761062  35.786344  0.944444
# Pelsmaeker,   0.000000  16.000000   9.500000  1.000000
# Planke,       0.000000  21.666667  18.000000  0.333333
# Royalty       0.000000  39.000000  13.860400  1.000000
# Shawah,       0.000000  30.000000   7.229200  1.000000
# ...

# %%
#correlation between FamilySize and SIbSp and Parch
A4['FamilySize']=A4['SibSp']+A4['Parch']
A4
A6=A4.filter(['Survived','FamilySize'])
plot_correlation_map(A6)

# %%
A7=A4.filter(['FamilySize','Survived','Sex','Age','Fare'])
A7[['FamilySize','Survived','Sex','Age','Fare']].groupby(['FamilySize'],as_index=True).mean()
#72% of famlies composed by 3 person survived and 50% of families composed of 1 to 2 person succeeded to survive.No families composed of more than 7 person survived
# Out:
#             Survived       Sex        Age       Fare
# FamilySize
# 0           0.303538  0.765363  31.595871  21.242689
# 1           0.552795  0.459627  31.160252  49.894129
# 2           0.578431  0.519608  26.359040  39.692482
# 3           0.724138  0.344828  19.062698  54.864510
# 4           0.200000  0.200000  23.186431  58.094453
# 5           0.136364  0.636364  18.409091  73.722727
# 6           0.333333  0.333333  15.166667  29.366667
# 7           0.000000  0.666667  15.666667  46.900000
# 10          0.000000  0.571429  29.699118  69.550000
